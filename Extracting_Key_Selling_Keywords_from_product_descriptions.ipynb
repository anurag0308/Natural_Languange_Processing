# %% [markdown]
# <a href="https://colab.research.google.com/github/anurag0308/Natural_Languange_Processing/blob/master/Extracting_Key_Selling_Keywords_from_product_descriptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Extracting Search Engine Appropriate Keywords and Key Selling Points from a Product's description in E-Commerce Websites
#
# **Problem Statement: Extract from mobile phone description dataset**
#
# 1. Search Engine Appropriate Keywords
#
# 2. Key Selling Points

# %% [markdown]
# **1. Extracting Search Engine Appropriate Keywords:**
#
# ---
# Proposed Approach:
#  Search engine appropriate keywords can be:
#
#   a. Specific : eg. Samsung Galaxy, Flip cover, Redmi note 3, etc. i.e. proper nouns
#
#   b. General :Features such as: Smartphone, earphone, tangle free earphone (nouns other than proper)
#
# ---
#
# **Solution: POS tagging + TFIDF + ngram**
#  For each document :
#
#    Extract Noun/ Proper nouns from preprocessed (stopwords+ lemmatization) text.
#
#    Join the extracted words to make a new document (pos_filtered_doc)
#
#  On list of pos_filtered_docs:
#
#     Apply ngram TFIDFVectorizer and for each document extract words with top-n TFIDF value.

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import nltk
from nltk.stem import WordNetLemmatizer 
from nltk.tokenize import word_tokenize

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/My Drive/amazon_phone_dataset.csv')

# %%
data.head()
# Out:
#                                         Product_name  ...                                        cust_review
# 0            Samsung Galaxy M10 (Ocean Blue, 3+32GB)  ...  Well, I was a bit sceptical before buying this...
# 1         Redmi 6 Pro (Black, 4GB RAM, 64GB Storage)  ...  Display quality is top notch, overall the qual...
# 2  Coolpad Cool 3 Plus (Ocean Blue, 2GB RAM, 16GB...  ...  Low bagget high kwality***It's not good Phone ...
# 3         Redmi 6 Pro (Black, 3GB RAM, 32GB Storage)  ...  Display quality is top notch, overall the qual...
# 4                                  Nokia 105 (Black)  ...  Using the mobile phone for last 3 months. I am...
#
# [5 rows x 11 columns]

# %%
data = pd.DataFrame({'Product_name':data['Product_name'],'prod_des':data['prod_des']}).dropna().reset_index(drop = True)

# %%
data
# Out:
#                                            Product_name                                           prod_des
# 0               Samsung Galaxy M10 (Ocean Blue, 3+32GB)  The Samsung Galaxy M10 is especially created f...
# 1            Redmi 6 Pro (Black, 4GB RAM, 64GB Storage)  Qualcomm Snapdragon 625, 2.0 GHz processor wit...
# 2     Coolpad Cool 3 Plus (Ocean Blue, 2GB RAM, 16GB...  Coolpad Cool 3 Plus-Designed for all, 5.71'' H...
# 3            Redmi 6 Pro (Black, 3GB RAM, 32GB Storage)  Qualcomm Snapdragon 625, 2.0 GHz processor wit...
# 4                                     Nokia 105 (Black)  The design Shaped for your palm Featuring a cu...
# ...                                                 ...                                                ...
# 3409  TokyoTon Mobile Battery for Moto M XT1662 XT16...  TokyoTon Mobile Battery for Moto M XT1662 XT16...
# 3410  AM Safe x Cable for iPhone LED Fast Charging D...  Fast Charging Nylon Braided USB LED Cable for ...
# 3411  Ktrack Metal and Plastic Open Pry Screwdriver ...  Product: Tool Metal and plastic. 8 in 1 tools ...
# 3412  Samsung S-View Flip Cover for Samsung Galaxy S...  The S-View Flip Cover, Clear allows you to see...
# 3413  TheGiftKart Full Body 3 in 1 Slim Fit 360 Degr...  DESCRIPTION:br>Beautiful design, elegant appea...
#
# [3414 rows x 2 columns]

# %% [markdown]
# **1. Search Appropriate Keywords**
#
# ---
#
# Search engine appropriate keywords can be:</br> a. Specific : eg. Samsung Galaxy, Flip cover, Redmi note 3, etc. i.e. proper nouns</br> b. General :Features such as: Smartphone, earphone, tangle free earphone (nouns other than proper)
#
# Task: To extract search engine appropriate keywords for a given product description

# %%
def extract_noun(doc):
  return ([i for i in nlp(doc) if i.pos_=='NOUN'],[i for i in nlp(doc) if i.pos_=='PROPN'])

# %%
data['noun_keywords'] =  data['prod_des'].apply(extract_noun)

# %%
df_noun_out = pd.DataFrame(data = {'Product_name': data['Product_name'],'prod_des':data['prod_des'],'keywords':data['noun_keywords']})

# %%
df_noun_out.head()
# Out:
#                                         Product_name  ...                                           keywords
# 0            Samsung Galaxy M10 (Ocean Blue, 3+32GB)  ...  ([millennials, edge, infinity, V, display, ang...
# 1         Redmi 6 Pro (Black, 4GB RAM, 64GB Storage)  ...  ([GHz, processor, nm, architecture, battery, c...
# 2  Coolpad Cool 3 Plus (Ocean Blue, 2GB RAM, 16GB...  ...  ([HD, dewdrop, display, GB, ROM, upto, sensor,...
# 3         Redmi 6 Pro (Black, 3GB RAM, 32GB Storage)  ...  ([GHz, processor, nm, architecture, battery, c...
# 4                                  Nokia 105 (Black)  ...  ([design, palm, body, island, layout, dialling...
#
# [5 rows x 3 columns]

# %%
df_noun_out.tail()
# Out:
#                                            Product_name  ...                                           keywords
# 3409  TokyoTon Mobile Battery for Moto M XT1662 XT16...  ...  ([], [TokyoTon, Mobile, Battery, Moto, M, XT16...
# 3410  AM Safe x Cable for iPhone LED Fast Charging D...  ...  ([USB], [Fast, Charging, Nylon, Braided, LED, ...
# 3411  Ktrack Metal and Plastic Open Pry Screwdriver ...  ...  ([Product, Metal, plastic, tools, scrapers, sc...
# 3412  Samsung S-View Flip Cover for Samsung Galaxy S...  ...  ([folio, complement, edge, calls, alarms, even...
# 3413  TheGiftKart Full Body 3 in 1 Slim Fit 360 Degr...  ...  ([DESCRIPTION, design, appearance, protection,...
#
# [5 rows x 3 columns]

# %%
df_noun_out.to_csv('df_pos_output.csv',index = False)

# %% [markdown]
# **2. POS + TF-IDF approach**

# %%
def tuple_to_list(t):
  l1,l2 = t
  l1.extend(l2)
  return [str(i) for i in l1]

# %%
data['keywords'] = df_noun_out['keywords'].apply(tuple_to_list)

# %%
data['keywords']
# Out:
# 0       [millennials, edge, infinity, V, display, angl...
# 1       [GHz, processor, nm, architecture, battery, ca...
# 2       [HD, dewdrop, display, GB, ROM, upto, sensor, ...
# 3       [GHz, processor, nm, architecture, battery, ca...
# 4       [design, palm, body, island, layout, dialling,...
#                               ...
# 3409    [TokyoTon, Mobile, Battery, Moto, M, XT1662, X...
# 3410    [USB, Fast, Charging, Nylon, Braided, LED, Cab...
# 3411    [Product, Metal, plastic, tools, scrapers, scr...
# 3412    [folio, complement, edge, calls, alarms, event...
# 3413    [DESCRIPTION, design, appearance, protection, ...
# Name: keywords, Length: 3414, dtype: object

# %%
df = [' '.join(i) for i in data['keywords']]

# %%
df
# Out:
# ['millennials edge infinity V display angle camera processor smartphone Samsung Galaxy M10 Galaxy M10',
#  'GHz processor nm architecture battery capacity cm camera portrait mode flash camera portrait mode Proximity sensor E compass Qualcomm Snapdragon FHD+ 1080x2280 Display GB GB Flash Memory Stock Android Oreo MP MP PDAF HDR LED MP Gyroscope Accelerometer IR Blaster',
#  'HD dewdrop display GB ROM upto sensor Support Coolpad Cool GB RAM GB Fingerprint Faceunlock Gradient ID Helio A22 Quad Core Processor Android Pie OTG',
#  'GHz processor nm architecture battery capacity cm camera portrait mode flash camera portrait mode Proximity sensor E compass Qualcomm Snapdragon FHD+ 1080x2280 Display GB GB Flash Memory Stock Android Oreo MP MP PDAF HDR LED MP Gyroscope Accelerometer IR Blaster',
#  'design palm body island layout dialling texting feeling quality phone palm hand battery hours talk time month dawn dusk companion day polycarbonate shell color flashlight games moment Nokia standby Nokia Snake Xenzia',
#  'G phone Inch touch screen display resolution pixels pixels processor GB phone GB storage GB card cameras G camera rear shooter selfies battery thickness grams G Connectivity options Sensors phone Proximity sensor sensor I Smart IS-58i I Smart IS-58i G Dual Core MediaTek RAM microSD I Smart IS-58i I Smart IS-58i G Android Naught height width I Smart IS-58i SIM GSM GSM Wi Fi Bluetooth FM Accelerometer Ambient',
#  'screen display design finish colors ocean cherry black others head device security faceunlock fingerprint unlock shooter sensor front beauty labels Dewdrop GB GB Upto GB Improved MediaTek Helio Processor Cool AI AI',
#  'Honor 9N smartphone design mirror effects definition phone one fact feature need shows phone viewing experience photographers phone manner store gamers feature hassle gaming experience Notch Display MP Front Camera MP Dual Rear Camera Game Suite',
#  'get viewing experience infinity V display shots rear camera apps beat Samsung Galaxy A10 gen',
#  'GHz processor battery capacity cm camera portrait mode flash camera portrait mode flash light Proximity sensor E compass Qualcomm Snapdragon FHD+ Display Stock Android Oreo MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster',
#  'GHz processor battery capacity cm camera portrait mode camera portrait mode Proximity sensor E compass Qualcomm Snapdragon 6.26-inch HD+ Dot Notch Display GB Flash Memory Stock Android Pie MP MP PDAF HDR MP Accelerometer IR Blaster',
#  'Infinity display time price display edge processor GB RAM box Samsung Galaxy M40 Samsung FHD+ Snapdragon Android Pie',
#  'millennials edge infinity V display angle camera processor smartphone Samsung Galaxy M10 Galaxy M10',
#  'G phone Inch touch screen display resolution pixels pixels processor GB phone GB storage GB card cameras G camera rear shooter selfies battery thickness grams G Connectivity options Sensors phone Proximity sensor sensor I Smart IS-58i I Smart IS-58i G Dual Core MediaTek RAM microSD I Smart IS-58i I Smart IS-58i G Android Naught height width I Smart IS-58i SIM GSM GSM Wi Fi Bluetooth FM Accelerometer Ambient',
#  'G phone Inch touch screen display resolution pixels pixels processor GB phone GB storage GB card cameras G camera rear shooter selfies battery thickness grams Connectivity options Sensors phone Proximity sensor sensor I Smart IS-59I I Smart IS-59I G Dual Core MediaTek RAM microSD I Smart IS-59I I Smart IS-59I G Android Naught height width I Smart IS-59I G SIM GSM GSM Wi Fi Bluetooth FM Accelerometer Ambient',
#  'Infinity display edge process GB box Samsung Galaxy M40 Samsung O Hole Display FHD+ Snapdragon SD675 Ram Android Pie',
#  'millennials edge infinity V display angle camera battery charging processor trust brand smartphone Toll Samsung Galaxy M20 Samsung Galaxy M20 Free No:1',
#  'millennials edge infinity U cut display camera setup processor battery smartphone Samsung Galaxy M30 Galaxy M30 3X',
#  'photos camera pixels lens beauty scene portrait mode background portraits core processor efficiency level performance AI AI Beautify',
#  'Memory storage storage GB slot G v8.0 system core processor SIM GB RAM GB SIM Operating System Processor Android Oreo Qualcomm Snapdragon',
#  'device day day life breeze operating system apps photos files touch button thanks HD screen 2.5D glass memory space G go connectivity AGPS navigation experience camera autofocus flash quality photos moment camera fun selfies connectivity network smartphones technology holiday home business life STK Life Plus S Smartphone Android Nougat GB GPS G Bluetooth V4.0 WiFi Android Nougat OS SIM',
#  'millennials edge infinity V display angle camera battery charging processor trust brand smartphone Toll Samsung Galaxy M20 Samsung Galaxy M20 Free No:1',
#  'support HD movies web browsing music streaming speeds Experience seamless network connectivity connection headset tablet device LTE Cat Wi Fi Bluetooth',
#  'phone photography level camera system display smartphone life moments picture clarity Honor Lite View FHD+',
#  'photos camera pixels lens beauty scene portrait mode background portraits core processor efficiency level performance AI AI Beautify',
#  'inch Mobile G phone inch touchscreen display resolution pixels pixels pixels inch GHz core processor GB phone GB storage GB cameras G camera battery mm weight grams G smartphone Connectivity options USB G Sensors phone Proximity sensor sensor Tashan VoLte PPI Tashan Model G Mediatek RAM upto Tashan Model Megapixel MP Front Camera Tashan Model G Android Naugot mAh Tashan Model SIM GSM GSM Micro SIM Micro SIM Wi Fi GPS Bluetooth NFC OTG FM Compass Magnetometer Accelerometer Gyroscope',
#  'selfie camera sensor selfie World 1st smartphone screen gold blue testing beauty features selfies skin tone eye shape U1 Realme Sony IMX576 AI India Helio P70 FHD+ Dewdrop',
#  'millennials edge infinity V display angle camera battery charging processor trust brand smartphone Toll Samsung Galaxy M20 Samsung Galaxy M20 Free No:1',
#  'processor battery Face unlock finger print sensor Panasonic P85 NXT GB RAM Snapdragon Mah',
#  'helio GHz core processor battery capacity cm display flash memory android camera flash camera portrait mode proximity sensor E compass accelerometer Mediatek A22 HD GB GB Oreo MIUI MP PDAF HDR MP',
#  'smartphone lineup budget offering company Nokia Nokia Android Nokia',
#  'selfie camera sensor selfie World 1st smartphone screen gold blue U1 Realme Sony IMX576 AI India Helio P70 FHD+ Dewdrop',
#  'photos camera pixels lens beauty scene portrait mode background portraits core processor efficiency level performance AI AI Beautify',
#  'Inch screen display ROM rear design finish others head device security face unlock fingerprint unlock +0.3 camera camera beauty labels Dewdrop GB GB Upto GB Cool AI MP Dual AI',
#  'helio GHz core processor battery capacity cm display flash memory android camera flash camera portrait mode proximity sensor E compass accelerometer Mediatek A22 HD GB GB Oreo MIUI MP PDAF HDR MP',
#  'CM)HD+19:9 autofocus camera mAh Google Assistant Face Unlock 5Mp Front Camera Xpress Covers Sold Seperately',
#  'GHz processor nm architecture battery capacity cm camera portrait mode flash camera portrait mode Proximity sensor E compass Qualcomm Snapdragon FHD+ 1080x2280 Display GB GB Flash Memory Stock Android Oreo MP MP PDAF HDR LED MP Gyroscope Accelerometer IR Blaster',
#  'Y91i smartphone camera front camera octa core processor memory cm view display battery Vivo MP MP Helio P22 GB RAM GB GB HD Halo',
#  'smartphone lineup budget offering company Nokia Nokia Android Nokia',
#  'fashion forward design world style fashion phone world style design finish phone phone use cards option rates communication music way headsetEnjoy convenience radio way phone speaker headset headset antenna listening option menu 1000mAh phone standout battery seamless connections go battery performance worries calls color display graphics fun excitement graphics photos fingertips color display image quality response time Philips E108 SIMThe SIM FM FM batteryYour Philips contacts.1.77 TFT TFT',
#  'speed HD display industry camera glass design OnePlus Snapdragon Full',
#  'speed HD display industry camera glass design OnePlus Snapdragon Full',
#  'inch camera system processor memory standby Samsung Galaxy A2 CORE Display Primary Camera MP F1.9 Flash F2.2 Android GO Exynos Ghz Octa Core GB RAM GB GB SIM G',
#  'GHz processor battery capacity cm camera portrait mode camera portrait mode Proximity sensor E compass Qualcomm Snapdragon 6.26-inch HD+ Dot Notch Display GB GB Flash Memory Stock Android Pie MP MP PDAF HDR MP Accelerometer IR Blaster',
#  'millennials edge infinity U cut display camera setup processor battery smartphone Samsung Galaxy M30 Galaxy M30 3X',
#  'phone inch touchscreen display resolution pixels pixels pixels inch G GHz core processor GB phone GB storage cameras G camera selfies battery mm weight grams smartphone Connectivity options USB G Sensors phone Proximity sensor sensor Ringme R1 Pro G VoLte Supported PPI Ringme Me8 Pro Mediatek RAM upto GB Ringme Me8 Pro Megapixel Front Camera Ringme R1 Pro G Android Ringme R1 Pro G SIM GSM GSM Micro SIM Micro SIM Wi Fi GPS Bluetooth NFC OTG FM Compass Magnetometer Accelerometer Gyroscope',
#  'GHz processor nm architecture battery capacity cm camera portrait mode flash camera portrait mode Proximity sensor E compass Qualcomm Snapdragon FHD+ 1080x2280 Display . GB GB Flash Memory Stock Android Oreo MP MP PDAF HDR LED MP Gyroscope Accelerometer IR Blaster',
#  'photos camera pixels lens beauty scene portrait mode background portraits core processor efficiency level performance AI AI Beautify',
#  'Y91i smartphone camera front camera octa core processor memory cm view display battery Vivo MP MP Helio P22 GB RAM GB GB HD Halo',
#  'Lava Z50 Black GB',
#  'GHz processor battery capacity cm camera portrait mode camera portrait mode Proximity sensor E compass Qualcomm Snapdragon 6.26-inch HD+ Dot Notch Display GB GB Flash Memory Stock Android Pie MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster',
#  'cm display cameras camera system day battery charging glass mind Battery rate slows progresses battery life claims user profile usage time battery performance factors signal strength network configuration age battery temperature device settings voice data application usage patterns g6 HD+ Max Vision',
#  'GHz processor battery capacity cm camera portrait mode camera portrait mode Proximity sensor E compass Qualcomm Snapdragon 6.26-inch HD+ Dot Notch Display GB GB Flash Memory Stock Android Pie MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster',
#  'speed flagship display industry camera glass design OnePlus',
#  'view display gorilla glass screen experience battery moment phone game music movies Fingerprint unlock moment phone touch occasion Fun',
#  'design volume experience button control product Metal dust net metal dust screen dust headphone interferes experience quality guarantee products surround voice switching quality call guarantee mode v4.1 power consumption device phones variety devices transmission distance meters feet performance lithium battery hours quality call time time hours Ears Connection press function button button lights phone connection Ears Connection press function button click side key state tone flashes ears connection pin charging cable package assistance seller manufacturer ZapTech All New Wireless Ear Air Plugs Bluetooth Headphone Exquisite 60mah Connect HBQ Single Ear Bluetooth function',
#  'metal housing design cavity unit HD sound calls music move hours music comfort Xmate Joy High Quality Wired Metal Earbuds mic remote',
#  'smartphones core processor performance power strength hassle apps camera picture quality experience face feature dot recognition points Mediatek Helio 0GHz Eluga X1 AI Eluga X1',
#  'TSC62 design LCD display phone memory call logs Panasonic KX SXB Phone Key Features Speaker Caller ID',
#  'view display gorilla glass screen experience battery moment phone game music movies Fingerprint unlock moment phone touch occasion Fun',
#  'GHz processor battery capacity cm camera portrait mode flash camera portrait mode flash light Proximity sensor E compass Qualcomm Snapdragon FHD+ Display Stock Android Oreo MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster',
#  'GHz processor battery capacity cm camera portrait mode camera portrait mode Proximity sensor E compass Qualcomm Snapdragon 6.26-inch HD+ Dot Notch Display GB GB Flash Memory Stock Android Pie MP MP PDAF HDR MP Accelerometer IR Blaster',
#  'helio GHz core processor battery capacity cm display flash memory android camera flash camera portrait mode proximity sensor E compass accelerometer Mediatek A22 HD GB GB Oreo MIUI MP PDAF HDR MP',
#  'millennials edge infinity U cut display camera setup processor battery smartphone Samsung Galaxy M30 Galaxy M30 3X',
#  'selfie camera sensor selfie World 1st smartphone screen gold blue U1 Realme Sony IMX576 AI India Helio P70 FHD+ Dewdrop',
#  'Wall Desk Mountable Ringer Volume Adjustment Corded Phone Flash Support Alphanumerical Keypad',
#  'Memory storage storage GB slot G v8.0 system core processor SIM GB RAM GB SIM Operating System Processor Android Oreo Qualcomm Snapdragon',
#  'desktop speaker phone color display voice quality phone user internet need plug phone line cable facility number list duration display selection- function log details Phone book memory ringtones Power LED indication Store memory menu connectivity Support protocol memory GB SD Card G402 G402 Hotspot SMS FM Radio Day Date Time Network Alarm Adapter SIM Hotline Dialing Music Player SD Card Jumbo Battery IPv4 IPv6 IPv4 IPv6 GB',
#  'photos camera pixels lens beauty scene portrait mode background portraits core processor efficiency level performance AI AI Beautify',
#  'speed OnePlus',
#  'inch Infinity F2.0 camera v9.0 system processor memory standby Samsung Galaxy A20 U Cut Display Primary Camera F1.9 Flash Android Pie Exynos Ghz Octa Core GB RAM GB GB SIM G',
#  'inch Infinity F2.0 camera v9.0 system processor memory standby Samsung Galaxy A20 U Cut Display Primary Camera F1.9 Flash Android Pie Exynos Ghz Octa Core GB RAM GB GB SIM G',
#  'processor architecture battery capacity cm inch display flash memory camera portrait mode LED flash camera portrait mode Proximity sensor e compass accelerometer blaster Qualcomm Snapdragon FHD+ GB Stock Android Oreo PDAF HDR gyroscope IR',
#  'looks functionality user experience GHz processor phone apps cm display dB level sound system videos games fun moment crystal pictures camera front camera Panasonic P95 Smartphone Qualcomm HD IPS MP MP',
#  'Colour Gold size name . display corner design hand feel cover glass edge risk display percent corner design display corner ground protection mesh volume reduction dust block | GB Speaker',
#  'GHz processor nm architecture battery capacity cm camera portrait mode flash camera portrait mode Proximity sensor E compass Qualcomm Snapdragon FHD+ 1080x2280 Display GB GB Flash Memory Stock Android Oreo MP MP PDAF HDR LED MP Gyroscope Accelerometer IR Blaster',
#  'millennials edge infinity V display angle camera processor smartphone Samsung Galaxy M10 Galaxy M10',
#  'devices ROM upto mAh Battery Sim G Volte Support GB RAM GB GB',
#  'inch Infinity F2.0 camera v9.0 system processor memory standby Samsung Galaxy A20 U Cut Display Primary Camera F1.9 Flash Android Pie Exynos Ghz Octa Core GB RAM GB GB SIM G',
#  'GHz processor battery capacity cm camera portrait mode flash camera portrait mode flash light Proximity sensor E compass Qualcomm Snapdragon FHD+ Display Stock Android Oreo MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster',
#  'smartphone notch screen processor performance power consumption battery worry battery standby front rear cameras beauty depth photos DSLR bokeh effect Night percent light light photography Hand night mode camera scenes scene types category labels time optimisation face password phone glance recognition feature GB ROM memory GB memory card freedom apps HUAWEI Y9 Hyper View Full Display Kirin mAh AI Beauty AI AI GB RAM Micro SD',
#  'smartphone camera selfie camera processor memory cm halo view display battery engine fast charging Vivo Y17 AI MediaTek P35 GB RAM GB GB 6.35-inch',
#  'display fingerprint sensor smartphone industry standard cutting edge technology OnePlus T Screen Unlock',
#  'power style mAh battery charging finish body videos screen quality pioneer phones quality Moto E5 Max Vision Motorola',
#  'budget segment smartphones end specs camera phone core chipset pixels LCD panel things features mode messages app Honor 7C Qualcomm Snapdragon Octa 5.99-inch IPS Honor 7C. Ride Mode knuckle gestures',
#  'speed flagship display industry camera glass design OnePlus',
#  'box HD+ pixels LCD display aspect ratio protection smartphone core GB Nokia Android Oreo Android One IPS Corning Gorilla Glass MediaTek MT6755S SoC RAM',
#  'looks functionality user experience GHz processor phone apps cm display dB level sound system videos games fun moment crystal pictures camera front camera Panasonic P95 Smartphone Qualcomm HD IPS MP MP',
#  '8X cm inch % screen body ratio AI camera features AI screen recognition motion photography technology night shots Honor 8X battery core chip variants RAM storage box EMUI skin top Honor LTPS Notch Display AI Octa HI Silicon Kirin GPU Turbo GB RAM GB GB RAM GB GB GB Android Oreo Huawei',
#  'Phone inch screen display features Call phone mobile language mother tongue BlackBear i7 Trio Exclusive Bluetooth Wireless FM Radio Java Games Snake Digital Camera Flash Inbuilt Memory Music Player Internet Browsing Social Networking Video Recording Notifications Bar Text Miss Battery Flip English Hindi Gujarati Bengali Urdu',
#  'Memory storage storage GB slot G system GHz core processor SIM GB RAM GB SIM Operating System Processor Android Oreo Cortex A53 Qualcomm MSM8953 Snapdragon Octa',
#  'GHz processor battery capacity cm camera portrait mode camera portrait mode Proximity sensor E compass Qualcomm Snapdragon 6.26-inch HD+ Dot Notch Display GB GB Flash Memory Stock Android Pie MP MP PDAF HDR MP Accelerometer IR Blaster',
#  'GHz processor battery capacity cm camera portrait mode camera portrait mode Proximity sensor E compass Qualcomm Snapdragon 6.26-inch HD+ Dot Notch Display GB Flash Memory Stock Android Pie MP MP PDAF HDR MP Accelerometer IR Blaster',
#  'Product Dimensions15.1 cm batteries Item model communication technologiesBluetooth technologies4 featuresDual camera features8MP camera Form factorTouchscreen OSAndroid RAM3 GB Item Weight159 g Batteries:1 Lithium Metal numberNokia Wireless WiFi Hotspot Connectivity G LTE Special SIM Phone Weight159 Grams ColourBlack Battery Power Rating3000',
#  'contrast color viewing experience millennials edge infinity U cut display camera setup processor battery smartphone Galaxy M30 Samsung Galaxy M30 Galaxy M30 3X',
#  'smartphone camera Pop processor memory display battery Vivo V15 Photosensitive AI Selfie Camera MediaTek P70 GB RAM GB GB FHD Ultra View Generation Corning Gorilla Glass Dual Engine Fast',
#  'smartphone camera processor memory cm battery Vivo Y15 AI Selfie Camera MediaTek Helio P22 GB RAM GB GB Halo Full View Display',
#  'millennials edge infinity V display angle camera battery charging processor trust brand smartphone camera selfies feed Toll Samsung Galaxy M20 Samsung Galaxy M20 In Display Flash Free No:1',
#  'processor battery Face unlock finger print sensor Panasonic P85 NXT GB RAM Snapdragon Mah',
#  'camera pixels resolution photos photography depth study face mapping features skin tone algorithm portrait background flash charge charging speed trickle period charge minutes version processor turbocharges performance fluidity responsiveness boost performance games apps operating system mp ffc algorithm Vooc helio p70 Hyper',
#  'speed flagship display industry camera glass design OnePlus',
#  'portrait light percent image sensors light portraits light camera quality pictures setting bar selfies camera battery Dual Rear Camera AI VOOC Flash Charge',
#  'speed flagship display industry camera glass design OnePlus',
#  '8C inches View video playing gaming experience battery days charge Honor 8C chipset storage box EMUI skin top camera features AI screen recognition light photography Honor Notch Display Qualcomm Snapdragon GB RAM GB Android Oreo AI',
#  'handset communication needs bar screen resolution pixels images display way navigation key applications pages phone ease alphanumeric phone pocket g measures mm dimensions Samsung Guru1200 GSM cm(1.52',
#  'galaxy device display centimeters AMOLED infinity u cut display resolution colours camera setup 16mp f1.9)+ 5mp angle camera 5mp flash 16mp camera Samsung A30 FHD+ ppi m f2.0',
#  'fashion forward design world style fashion phone world style design finish phone phone use cards option rates communication music way headsetEnjoy convenience radio way phone speaker headset headset antenna listening option menu 1000mAh phone standout battery seamless connections go battery performance worries calls color display graphics fun excitement graphics photos fingertips color display image quality response time Philips E108 SIMThe SIM FM FM batteryYour Philips contacts.1.77 TFT TFT',
#  '8X cm inch % screen body ratio AI camera features AI screen recognition motion photography technology night shots Honor 8X battery core chip variants RAM storage box EMUI skin top Honor LTPS Notch Display AI Octa HI Silicon Kirin GPU Turbo GB RAM GB GB RAM GB GB GB Android Oreo Huawei',
#  'GHz processor battery capacity cm camera portrait mode flash camera portrait mode flash light Proximity sensor E compass processor performance consumes power perfromance life visuals clock speed performance Qualcomm Snapdragon FHD+ Display Stock Android Oreo MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster nm FinFET Adreno GPU',
#  'galaxy device fingerprint sensor centimeters AMOLED infinity u cut display resolution colours camera setup 16mp f1.9)+ 5mp angle camera 5mp flash camera Samsung A50 FHD+ ppi',
#  'view display glass screen experience battery moment phone game music movies moment phone touch occasion Corning Gorilla Fun Fingerprint Unlock Unlock',
#  'portrait light percent image sensors light portraits light camera AI camera quality pictures setting bar selfies camera battery flash charge VOOC',
#  'camera pixels resolution photos photography depth study face mapping features skin tone algorithm portrait background flash charge charging speed trickle period charge minutes version p70 processor turbocharges performance fluidity responsiveness boost performance games apps operating system MP ffc algorithm Vooc Helio 2.1ghz Hyper',
#  'body island layout dialing texting feeling quality phone palm hand battery hours talk time month dawn dusk Nokia standby',
#  '4X ” View display 2.5D screen touch gaming experience RAM memory Front present mAh 1.5Ghz XOLO ERA GB HD+ IPS Corning Gorilla Glass GB GB Internal GB Screen Flash LED Flash Camera Phone AI Battery MediaTek Quad Core Processor Dual G VoLTE',
#  'Oppo debut RAM/ board storage RAM/ storage options smartphone core camera setup selfie camera India GB GB GB GB Snapdragon SoC Oppo AI Beauty Technology',
#  'core . . inches cm)720x1570 px ppiips camera camera battery usb type c port bands sim fingerprint sensor gorilla radio Octa ghz quad core ghz quad core snapdragon gb ram MP flash8 MP mAh power volte64 gb gb Nano Nano glass 3fm',
#  'edition box sports HD pixels aspect ratio coating phone GB LPDDR3 battery hood battery life Nokia Android Oreo Qualcomm Snapdragon SoC RAM',
#  'smartphone notch screen processor performance power consumption battery worry battery standby front rear cameras beauty depth photos DSLR bokeh effect Night percent light light photography Hand night mode camera scenes scene types category labels time optimisation face password phone glance recognition feature GB ROM memory GB memory card freedom apps HUAWEI Y9 Hyper View Full Display Kirin mAh AI Beauty AI AI GB RAM Micro SD',
#  'R7S G Smartphone choice GB ROM R7S battery day backup GB RAM Forme Budget Phone Users Forme R7 GB RAM Mediatek Super Fast Processor Rear Camera Front Camera Flash',
#  'phone world G Phone phone world G size radiation parameter radiations cellphone radiation 2.1w kg cellphone battery backup bulk size feather weight cigarette phone operations music call phone voice changer experience Warranty YEAR MANUFACTURER ONSITE Vaku Luxos World Smallest Dual Sim Nano Phone Voice Changer Alarm Bluetooth LBSTAR World Dual Sim Nano Phone Voice Changer Alarm Smallest Features Smallest Bluetooth Phone 0.283w kg Compact Polymer Battery Bluetooth Dialer Sim Dual Standby Mode WARRANTY',
#  'processor battery Face unlock finger print sensor Panasonic P85 NXT GB RAM Snapdragon Mah',
#  'screen battery processor hours streaming recording phone worry camera camera K video recording ensures moments way FHD+ G2 pixel',
#  'speed HD display industry camera glass design OnePlus Snapdragon Full',
#  'experience courtesy breakthrough technology Pop motor phone body movements camera seconds smartphone Pixel)+8MP+5MP camera Pop processor memory display battery FullView Selfie Camera Vivo V15 Pro Quad Pixel Sensor AI World Selfie Camera Qualcomm Snapdragon GB RAM GB GB FHD+ Super AMOLDED Ultra Fullview Dual Engine Fast',
#  'GHz processor battery capacity cm camera portrait mode camera portrait mode Proximity sensor E compass Qualcomm Snapdragon 6.26-inch HD+ Dot Notch Display GB GB Flash Memory Stock Android Pie MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster',
#  'GHz processor battery capacity cm camera portrait mode flash camera portrait mode flash light Proximity sensor E compass Qualcomm Snapdragon FHD+ Display . GB GB Flash Memory Stock Android Oreo MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster',
#  'GHz processor battery capacity cm camera portrait mode camera portrait mode Proximity sensor E compass Qualcomm Snapdragon 6.26-inch HD+ Dot Notch Display GB Flash Memory Stock Android Pie MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster',
#  'smartphone camera selfie camera processor memory cm halo fullview display battery Vivo Y12 AI MediaTek Helio P22 GB RAM GB GB 6.35-inch',
#  'processor architecture battery capacity cm inch display flash memory camera portrait mode LED flash camera portrait mode Proximity sensor e compass accelerometer blaster Qualcomm Snapdragon FHD+ GB Stock Android Oreo PDAF HDR gyroscope IR',
#  'smartphone camera selfie camera processor memory cm halo fullview display battery Vivo Y12 AI MediaTek Helio P22 GB RAM GB GB 6.35-inch',
#  'galaxy device fingerprint sensor centimeters AMOLED infinity u cut display resolution colours camera setup 16mp f1.9)+ 5mp angle camera 5mp flash camera Samsung A50 FHD+ ppi',
#  'portrait light percent image sensors light portraits light camera AI camera quality pictures setting bar selfies camera battery flash charge VOOC',
#  'phone world G Phone phone world G size radiation parameter radiations cellphone radiation 2.1w kg cellphone battery backup bulk size feather weight cigarette phone operations music call phone voice changer experience Warranty YEAR MANUFACTURER ONSITE Vaku Luxos World Smallest Dual Sim Nano Phone Voice Changer Alarm Bluetooth LBSTAR World Dual Sim Nano Phone Voice Changer Alarm Smallest Features Smallest Bluetooth Phone 0.283w kg Compact Polymer Battery Bluetooth Dialer Sim Dual Standby Mode WARRANTY',
#  'smartphone camera selfie camera processor memory cm halo view display battery engine fast charging Vivo Y17 AI MediaTek P35 GB RAM GB GB 6.35-inch',
#  'speed OnePlus',
#  'iVOOMi bundle features Boasting edges phone View display screen ratio screen size cm functions GHz core processor . processing power GB loads storage space battery days battery life iVOOMi camera flash sensor lens selfie camera lens phone G sim OS phone feature connectivity options others iVOOMi formats phone brand warranty i2 Lite HD+ MediaTek GB RAM ROM GB mAh 2A fast i2 Lite Sony 5P Largan MP Samsung Largan VoLTE Slots Android Oreo Face Unlock Wi Fi OTG Bluetooth i2 Lite ACC AMR MP3 WAV',
#  'smartphone camera selfie camera processor memory cm halo fullview display battery Vivo Y12 AI MediaTek Helio P22 GB RAM GB GB 6.35-inch',
#  'TA-1154 DS black platform Nokia Android vPie Qualcomm Snapdragon Quad Core',
#  'Sms Card Battery phone Name Memory Gsm Quad Band Sms Store Messages Fw200L Base Messages Sim Long Rechargeable Battery Life Name Number Phonebook Fw200L Base Contacts Sim Card Black White Backlit Display Hands Free Speaker Ringer Melodies User Selectable Number Caller List Redial',
#  'screen Z61',
#  'phone photography level camera system display smartphone life moments picture clarity Honor Lite View FHD+',
#  'get viewing experience infinity V display shots rear camera apps beat Samsung Galaxy A10 gen',
#  'smartphone Pixel)+8MP+5MP camera Pop processor memory display battery experience courtesy breakthrough technology Pop motor phone body movements camera seconds Vivo V15 Pro Quad Pixel Sensor AI World Selfie Camera Qualcomm Snapdragon GB RAM GB GB FHD+ Super AMOLDED Ultra Fullview Dual Engine Fast FullView Selfie Camera',
#  'GHz processor battery capacity cm display flash memory camera portrait mode flash camera portrait mode flash light proximity sensor e compass accelerometer blaster Qualcomm snapdragon FHD+ gb gb Miui android MP MP PDAF HDR MP gyroscope IR',
#  'view display gorilla glass screen experience battery moment phone game music movies Fingerprint unlock moment phone touch occasion Fun',
#  '8C inches View video playing gaming experience battery days charge Honor 8C chipset storage box EMUI skin top camera features AI screen recognition light photography Honor Notch Display Qualcomm Snapdragon GB RAM GB Android Oreo AI',
#  'f1.79 f2.2 3P GB UP Gold GHz Silver GHz v5.1 2.5D USB C E - compass % 2.5D front Notch Display 4-in-1 Primary 6P Lens Secondary Lens PDAF AI Dual Camera Qualcomm Snapdragon 675,Octa Core Android Pie GB RAM Internal GB Processor eMMC Body Glass Type IR Blaster Charger Super Low Light Mode Quick Charge Dual VoLTE Two Days Battery Aura Design Gradient Reflective Glass EIS Video Recording Studio Lighting Rear Fingerprint Scanner Ambient Light Sensor Proximity Sensor Accelerometer Gyroscope Sony IMX586 Sensor Contrast Ratio NTSC Ratio Glass Corning Gorilla Glass Front Glass Dot',
#  'Test ASIN',
#  'smartphones core processor performance power strength hassle apps camera picture quality experience face feature dot recognition points Mediatek Helio 0GHz Eluga X1 AI Eluga X1',
#  'smartphone Pixel)+8MP+5MP camera Pop processor memory display battery Vivo V15 Pro Quad Pixel Sensor AI World Selfie Camera Qualcomm Snapdragon GB RAM GB GB FHD+ Super AMOLDED Ultra View Dual Engine Fast',
#  'Ismart I6 G phone inch touchscreen display resolution pixels pixels pixels inch I6 G GHz core processor GB phone GB storage cameras I6 G camera selfies I6 G battery mm weight grams I6 G smartphone Connectivity options USB G Sensors phone Proximity sensor sensor VoLte Supported PPI Ismart Mediatek RAM upto GB Ismart Megapixel Front Camera Ismart Android Ismart SIM GSM GSM Micro SIM Micro SIM Wi Fi GPS Bluetooth NFC OTG FM Compass Magnetometer Accelerometer Gyroscope',
#  'screen inch display product gorilla glass protection touch display touch experience software oreo RAM memory processor processing handset BIS certificates product Z61E HD+ Android edition GB GB Internal CB CE FCC SAR RoHS',
#  'design volume experience button control product Metal dust net metal dust screen dust headphone interferes experience quality guarantee products surround voice switching quality call guarantee mode v4.1 power consumption device phones variety devices transmission distance meters feet performance lithium battery hours quality call time time hours Ears Connection press function button button lights phone connection Ears Connection press function button click side key state tone flashes ears connection pin charging cable package assistance seller manufacturer ZapTech All New Wireless Ear Air Plugs Bluetooth Headphone Exquisite 60mah Connect HBQ Single Ear Bluetooth function',
#  'entertainment features experiences user experience screen internet browsing pictures videos gaming access web content apps games selfies moments withfriends family Nokia Nokia Opera Mini Browser Opera Mobile Store Facebook',
#  'GHz processor battery capacity cm camera portrait mode camera portrait mode Proximity sensor E compass Qualcomm Snapdragon 6.26-inch HD+ Dot Notch Display GB Flash Memory Stock Android Pie MP MP PDAF HDR MP Accelerometer IR Blaster',
#  'galaxy device fingerprint sensor centimeters AMOLED infinity u cut display resolution colours camera setup 16mp f1.9)+ 5mp angle camera 5mp flash camera Samsung A50 FHD+ ppi',
#  'edge edge display camera camera tone metal frame date platform RAM storage battery flash 2nd depth sensing camera HD+ ZEISS Optics OIS Android Pie Qualcomm Snapdragon GB GB Camera rear-12MP 1/2.55 OIS EIS ZEISS Hi Cri FF front-20M/ FF/0.9um',
#  'meaning immersion display massive screen life experience hand Canvas Infinity',
#  'inch camera system processor memory standby Samsung Galaxy A2 CORE Display Primary Camera MP F1.9 Flash F2.2 Android GO Exynos Ghz Octa Core GB RAM GB GB SIM G',
#  'phone photography level camera system display smartphone life moments picture clarity Honor Lite FullView FHD+',
#  'rom cm inch display camera battery processor gb ram | gb | fhd+ | mAh qualcomm snapdragon',
#  'TA-1161 steel platform Nokia DS Android vPie Qualcomm Snapdragon Quad Core',
#  '8X cm inch % screen body ratio AI camera features AI screen recognition motion photography technology night shots Honor 8X battery core chip variants RAM storage box EMUI skin top Honor LTPS Notch Display AI Octa HI Silicon Kirin GPU Turbo GB RAM GB GB RAM GB GB GB Android Oreo Huawei',
#  'GHz processor nm architecture battery capacity cm camera portrait mode flash camera portrait mode Proximity sensor E compass Qualcomm Snapdragon FHD+ 1080x2280 Display GB GB Flash Memory Stock Android Oreo MP MP PDAF HDR LED MP Gyroscope Accelerometer IR Blaster',
#  'portrait light percent image sensors light portraits light camera AI camera quality pictures setting bar selfies camera battery flash charge VOOC',
#  'screen battery processor hours streaming recording phone worry camera camera K video recording ensures moments way FHD+ G2 pixel',
#  'screen battery processor hours streaming recording phone worry camera camera K video recording ensures moments way FHD+ G2 pixel',
#  'camera Days warranty Micromax X725 Dual Selfie Wireless FM Radio',
#  'camera ultra mode mode mode mo time lapse photography camera filter photo mode mode face beauty palm capture gender detection stickers face time watermark selfie lighting scene recognition portrait framing camera centimeters touchscreen pixels resolution density system core processor memory standby lithium ion battery year manufacturer warranty device months manufacturer warranty box accessories batteries date purchase AMOLED display experience pixel+5MP HD ppt bokeh HDR AI panorama retina flash AR AI AI AI google lens AI 6.41-inch AMOLED FHD+ ppi pixel Android Oreo Funtouch Qualcomm Snapdragon GB RAM GB GB SIM nano+nano G Dual Engine Super',
#  'inch SIM Screen Size Power Bank Function',
#  'camera pixels resolution photos photography depth study face mapping features skin tone algorithm portrait background flash charge charging speed trickle period charge minutes version processor turbocharges performance fluidity responsiveness boost performance games apps operating system mp ffc algorithm Vooc helio p70 Hyper',
#  'Samsung Guru FM Feature Phone Performance',
#  'galaxy device fingerprint sensor centimeters AMOLED infinity u cut display resolution colours camera setup camers Samsung A50 FHD+ ppi F1.7 F2.2 Angle F2.2 Flash | MP F2.0',
#  'aie processor benchmark smartphone segment dewdrop screen screen body ratio percent smartphones segment variants ram gb rom ram rom pro treat entertainment gaming addicts cm screen screen body ratio phone design screen aie intelligence engine processor gb ram smartphone efficiency performance Realme snapdragon gb ram gb rom gb gb gb Realme qualcomm snapdragon Realme',
#  'camera centimeters display pixels operating system MB RAM MB memory lithium year manufacturer warranty device months manufacturer warranty box accessories batteries date purchase LED GB SIM ion;1',
#  'GHz processor battery capacity cm camera portrait mode flash camera portrait mode flash light Proximity sensor E compass Qualcomm Snapdragon FHD+ Display Stock Android Oreo MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster',
#  'speed OnePlus',
#  'Colour size name . display corner design hand feel display world core processor technology system level optimisations power consumption battery life quality camera photos lighting conditions portraits features | GB Qualcomm snapdragon nm finfet Miui beautify',
#  '8X cm inch % screen body ratio AI camera features AI screen recognition motion photography technology night shots Honor 8X battery core chip variants RAM storage box EMUI skin top Honor LTPS Notch Display AI Octa HI Silicon Kirin GPU Turbo GB RAM GB GB RAM GB GB GB Android Oreo Huawei',
#  'Infinity display time price display edge processor GB RAM box Samsung Galaxy M40 Samsung FHD+ Snapdragon Android Pie',
#  'smartphone camera Pop processor memory display battery Vivo V15 Photosensitive AI Selfie Camera MediaTek P70 GB RAM GB GB FHD Ultra FullView Generation Corning Gorilla Glass Dual Engine Fast',
#  'colour phone Matte Blue',
#  'core processor technology battery days time storage sim slot Qualcomm snapdragon nm finfet GB RAM GB GB',
#  'galaxy device display centimeters AMOLED infinity u cut display resolution colours camera setup 16mp f1.9)+ 5mp angle camera 5mp flash 16mp camera Samsung A30 FHD+ ppi m f2.0',
#  'GHz processor battery capacity cm display flash memory camera portrait mode flash camera portrait mode flash light proximity sensor e compass accelerometer blaster Qualcomm snapdragon FHD+ gb gb Miui android MP MP PDAF HDR MP gyroscope IR',
#  '4X ” View display 2.5D screen touch gaming experience RAM memory Front present mAh 1.5Ghz XOLO ERA GB HD+ IPS Corning Gorilla Glass GB GB Internal GB Screen Flash LED Flash Camera Phone AI Battery MediaTek Quad Core Processor Dual G VoLTE',
#  '4X ” View display 2.5D screen touch gaming experience RAM memory Front present mAh 1.5Ghz XOLO ERA GB HD+ IPS Corning Gorilla Glass GB GB Internal GB Screen Flash LED Flash Camera Phone AI Battery MediaTek Quad Core Processor Dual G VoLTE',
#  'Light Number Redial Supply Call Recording G voice data Way Sms Voice Mail Caller ID Loud Speaker Phone Voice Communication Large LCD Status Icon TNC Antena Touch Memory Long Battery Power Talk Time FM Radio Button Ac Power GSM G Box Contains Handset Battery Handset Cord TNC Antenna Power Adapter User Manual',
#  'user experience phone features times',
#  'benefits display ratio battery life batteryÂ¹ life charge portrait photos camera Bokeh photo date Nokia Nokia Android Oreo',
#  'galaxy device fingerprint sensor centimeters AMOLED infinity u cut display resolution colours camera setup 16mp f1.9)+ 5mp angle camera 5mp flash camera Samsung A50 FHD+ ppi',
#  'camera camera15.74 centimeters touchscreen pixels resolution Color OS system core processor memory standby lithium ion battery Android Oreo Qualcomm Snapdragon GB RAM GB GB SIM nano+nano 4G+4 G',
#  'Curve device buyer range features friends family bar shape QWERTY keyboard phone OS MB RAM Curve',
#  'Equalizer Call Barring,100 Name Station Call Hours Talk Time Hopping Spread Spectrum Digital Technology Customised Sound System[Bass Normal Treble].Power Operation Incoming Number Phone Book Polyphonic Ringer Handset:30Melodies/10Tones Caller Log Wall Mountable Base Unit Battery Life Upto Rechargeable Batterries',
#  'screen battery processor hours streaming recording phone worry camera camera K video recording ensures moments way FHD+ G2 pixel',
#  'design quality communication SIM groups contacts life contacts phone numbers phones cm QVGA K color display graphics fun excitement graphics photos phone cm QVGA K color display image quality response time fingertips battery phone battery seamless connection go battery performance work family call camera camera VGA resolution pixels moments life phone Press camera key pictures wallpaper fotocall music way headset convenience radio way phone speaker headset headset antenna listening option menu grope dark keys light flashlight phone light situation Philips E168 Battery Display FM Radio SIM SIM TFT TFT Superb Philips MMS.Enjoy FM -Enjoy FM',
#  'smartphone experience FullVisionU mAh battery smartphone experience camera Sensor degree Depth Camera15.9 centimeters vision dot display pixels resolution % Screen memory standby v9.0 system nm technology lithium polymer battery year manufacturer warranty device months manufacturer warranty box accessories batteries date Ejector Pin LG W30 Smartphone Drop Display AI Triple Rear Camera G VoLte Android Pie ","Triple Rear Camera MP Low Sony IMX Camera MP Wide Angle distortion)PDAF Camera 6.26-inch Aspect Ratio Body RatioMemory Storage SIM GB RAM |32 GB GB | Dual SIM nano+nano Pie Mediatek Helio P22 CPU octa core processor4000mAH Face Unlock Finger Print Sensor1 purchaseBox Charger Quick Start Guide USB Data Cable SIM',
#  'generation corning glass screen Screen ration % area screen display area battery value lens cameras output output settings ° temperature % brightness phone screen decrease test conditions A7 CG A7 A7 pixel A5',
#  'galaxy device fingerprint sensor centimeters AMOLED infinity u cut display resolution colours camera setup 16mp f1.9)+ 5mp angle camera 5mp flash camera Samsung A50 FHD+ ppi',
#  'Feel quality components types adversity country maintenance use phone purpose terminals telephone LED indication Antique Collection Phone Royal Telephone India home office Technical Specification Ringer Lo Switch Tone Pulse Switch Mute Button Flash Button Redial Button Ringer Desk Wall Mountable',
#  'smartphone Pixel)+8MP+5MP camera Pop processor memory display battery Vivo V15 Pro Quad Pixel Sensor AI World Selfie Camera Qualcomm Snapdragon GB RAM GB GB FHD+ Super AMOLDED Ultra View Dual Engine Fast',
#  'smartphone camera camera processor memory cm battery Vivo Y91 GB RAM GB Storage MP MP AI MP Qualcomm Snapdragon Octa Core GB RAM GB GB Halo FullView Display',
#  'control level performance GHz processor battery capacity cm camera portrait mode flash camera portrait mode flash light Proximity sensor E compass Flagship Qualcomm Snapdragon FHD+ Display Stock Android Oreo MP MP PDAF HDR MP Gyroscope Accelerometer IR Blaster',
#  'Incoming Call Memory Way Speaker Phone LCD Backlight Rechargable AAA Battery Phone Book Illuminated Keypad Alarm Function Polyphonic Ringtones',
#  'phone feature lcd screen language radio mp3 storage sim card call recorder auto call recorder conference call emergency call hands sms reply/ call transfer ringtone contents unit base unit handset power adaptor battery signal trays warranty service product defects period year Hindi English FM mAh micro usb cable booster antenna sim',
#  'issue product contact brand hours Incase Service',
#  'inches face unlock sim card reference Bliss Tashan Phone Display 6.0 Android mAh Battery,4 G Note Images',
#  'bezel design distraction screen AMOLED display viewing experience advantage design side styling grips hand design users move life adventures day night camera sensors user noise reduction selfies environments Galaxy A8 Star HD+ Super Galaxy A8 Star Galaxy A8 Star',
#  'Memory storage storage GB slot G operating system core processor SIM GB RAM GB SIM Operating System Processor Android Oreo MIUI Snapdragon',
#  'smartphone camera camera experience Detection feature camera picture images thanks technology size aperture offer light photography experience core processor mAh capacity battery smartphone performance days battery life Redmi Note Pro Xiaomi AI AI Scene Dual Pixel Autofocus micrometre pixel Qualcomm Snapdragon',
#  'segment display touch memory keys Hands speakerphone way purpose function music number calls ringer melodies number redial pulse voicemail indicator B+W Caller ID Tone Network',
#  'Card microSDXC cards pictures app performance HD video.(1 smartphones tablets cards apps smartphone experience products standards quality performance reliability product SanDisk Ultra UHS Adapter SanDisk Ultra microSDHC Ideal Android SanDisk SanDisk',
#  'camera pixels resolution photos photography depth study face mapping features skin tone algorithm portrait background flash charge charging speed trickle period charge minutes version p70 processor turbocharges performance fluidity responsiveness boost performance games apps operating system MP ffc algorithm Vooc Helio 2.1ghz Hyper',
#  'smartphone camera processor memory cm battery Vivo Y15 AI Selfie Camera MediaTek Helio P22 GB RAM GB GB Halo Full View Display',
#  'sim phone times multimedia options dul moment lithium ion battery capacity mp3 player torch light gsm-900/1800mhz sim ram memory gb currency detector light feature display day.800 mAh mp4 mp camera bluetooth gprs Mb',
#  'ultra UHS card video SanDisk HD',
#  'desktop speaker phone voice quality phone need plug phone line cable facility number list duration display selection- function log details Phone book memory ringtones Power LED indication Store memory menu G201 G201 SMS FM Radio Day Date Time Network Alarm Adapter SIM Hotline Dialing',
#  'features cm display edges display grip iVooMi advantage GHz processor RAM battery experience GB memory space media files photos phone camera flash selfie camera picture photos messaging fun operating system phone iVooMi connectivity life feature connectivity dearth convenience features smartphone addition iVooMi formats mp3 playlists stylish iVooMi iPro+ FullView iPro+ Quad Core MediaTek GB mAh GB MP MP Beauty Mode AR Android Oreo Go Edition iPro SIM Face Unlock Wi Fi OTG iPro AAC AMR WAV',
#  'X-81 Cordless Phone Ghz Beetel',
#  'GHz processor architecture battery capacity cm inch display flash memory camera portrait mode LED flash camera portrait mode Proximity sensor e compass accelerometer blaster Qualcomm snapdragon FHD+ Stock Android Oreo PDAF HDR gyroscope IR',
#  'Honor 9N smartphone design mirror effects definition phone one fact feature need shows phone viewing experience photographers phone manner store gamers feature hassle gaming experience Notch Display MP Front Camera MP Dual Rear Camera Game Suite',
#  'flash ringer switch pause flash land line phone Tone/',
#  'Memory storage storage GB slot standby G G networks cards G system GHz core processor SIM GB RAM GB SIM SIM System Processor Android Oreo Cortex A53 Qualcomm MSM8953 Snapdragon Octa',
#  'microphone Smartphones recorders PC video use pickup pattern ‚ coverage possibility sight cable gold plug thing smartphones cameras percent choice sound presentations video recorders Smartphone microphone OFF power Camcorders audio recorders PC microphone OFF smartphones Camcorders audio recorders PC microphone Quality condenser video use noise Transducer type condenser Pattern frequency range noise SPL Sensitivity Output impedance Ohm output connection mm gold plug Battery Dimension cable ft Weight Microphone g Power module g Package contents condenser audio cable lapel clip foam windscreen adapter battery user manual Boya BY M1 Omni DSLR Camcorders Audio Omni Note ON OFF Smartphone DSLR ON ON mic DSLR Omni 18KHz Signal -30dB /-3dB 1V Pa Type LR44 Microphone:18.00 mm mm mm m Boya Omnidirectional Lavaliere microphone-20 ft LR44',
#  'Inch Display VGA Camera Sim Stand Cable Kechaoda K33 € € Sim Keypad Mobile € Flash Light € External Memory GB € mAh Capacitive Battery € € Bluetooth Dialer € Audio Jack € Chipset € Box 1Brand New Handset USB',
#  'device display centimeters Infinity PPI setup angle camera F2.0 camera Samsung Galaxy A30 Super Amoled U Cut Display FHD+ Resolution M Colours Camera F1.9)+ 5MP(2.2 Flash',
# ...
#  'GSM+GSM cm Feature(You Phone phone Call Memory upto Internet LED Torch Days Note mobile city product Jivi N3333 Powerbank Phone Specs Sim Display Digital Camera mAh Marathon Battery Powerbank Bluetooth Wireless FM Radio Auto GB MP3 MP4 Player Audio Jack Light Replacement Warranty Replacement Jivi Service Centres India',
#  'phone wireless dialler headset phone year product colour product Gold Bliss FM Finger Bluetooth Warranty',
#  'display Days replacement year warranty handset months warranty Unlimited Power Battery accessories(T&C Apply',
#  'car design mobile rock sim gsm camera box red CLUBCLASSY flip charger dosent',
#  'GHz processor battery capacity cm display flash memory camera portrait mode flash camera portrait mode flash light proximity sensor e compass accelerometer blaster Qualcomm snapdragon FHD+ gb gb MIUI android MP MP PDAF HDR MP gyroscope IR',
#  'metal earphones experience brand clarity earphone metal tangle cables headphones mm drivers sound bass noise calls colors style day earphones choice attitude BassHeads Super Extra Bass mic boAt nirvana',
#  'Results headphones workout motivation sound design ear ear fit convenience combination ear tips technology buds Thanks sweat proof headphones step sweat rain workout playback hours line microphone hands control sound calls buds neck use workout JBL Endurance RUNBT JBL Flip Hook Flex Twist Lock IPX5 JBL Endurance RUNBT JBL Endurance RUNBT Endurance RUNBT',
#  'Description % Brand quality phone bracket stretch phone Phone bracket stretch hole slot padded sides tier sponge clamps love machine - cm width',
#  'devices finish TOUGH Fingerprint proof tear dream treat eyes lip build design screen surface Case Edges screen scratches Scratch durability case Phone comfort use phone opening skin device design button seamless compatibility fitting installation case chance loss case phone resistance profile design ease comfort handling weight bulk cases Case Phone Message customers products purchases orders business day delivery products world class services brands GoldKart Gold Series Matte Finish Hard Cases Matte Density PolyCarbonate Matte Finish Minimalist Matte Finish Super Proof Scratch Proof Maximum Protection Precise Cutouts Slim Form Fitted Corner Impact Feather Light Feather Light Package Content GoldKart Seller',
#  'joystick hand fatigue game buttons experience button staff pugb game quality sensitivity products quality Gamepad Gamepad',
#  'front flash screen flash selfies light time dollar smile show Love looks selfies feature filters picture look beauty hands holder analysis selfie S6s sensor aperture picture quality click LED flash brightness night light shots curves lines impression grip camber selfies CRI Gionee S6s Live Filter Face Beauty camera Sony 5P lens Camera Phone',
#  'view display DT glass scratch experience smartphone smartphone face unlock security device photography skills peer group filters features Beauty mode Photo video videos face Bokeh mode camera QR code scanner weight video calls night Face click moments days replacement guarantee Screen breakage warranty case phone defect customer smartphone rest assure servicing service centres Comio X1 HD+ AI- MP Auto Focus Rear Camera gm MP Selfie Camera Flash AI- Cute Portrait Mode Comio X1 Comio India',
#  'Arm arm height view Warranty worry lifetime support Warranty',
#  'USB wall needs power 6.3A power devices technology devices current speed power charging power charge devices family charger USB wall needs phones tablets MP3 players USB devices device chargers charger charger family safeguards devices charging accessibility place devices charging accessibility place charger job USB outlets queue vigil places travel charger power supply quality materials life construction sustain use Product Name Output USB SmartQ total Dimensions g Color Fast Charging iPad iPhones QuantumZERO Safety Guaranteed Multiple Small Specifications Product 31W Wall Charger Product Model QZ WC18 Power 31W Input AC mm Weight White Package Contents 31W Wall Charger Guide',
#  'blend design technology S9 + plethora features reality emoji core processor GB AMOLED display surround sound technology theatre videos moments camera camera Samsung Super Slow Live Translation Intelligent Scan RAM HD+ Super Dolby Atmos MP MP MP',
#  'quality access buttons controls ports phone scratches damages dust phone access buttons controls ports ✔ Genuine Premium ✔ Easy Lightweight ✔',
#  'footprint design adapts environments key ringtone desk wall hotel rooms meeting rooms supermarket checkouts Alcatel T06',
#  'look peace mind armor protection case silicon interior quality polycarbonate case outside layer armor shield bumps scratches layer device shock absorption impact shell corners protection bumps impacts Hybrid casing protection weight phone design grip handling case basis Case kickstand hands viewing movies video chat convenience landscape format mechanism stability phone case stand cut outs access ports functionality Case minutes installation case phone layer fit sides buttons layer place device Bracevor Rugged Armor Hybrid Kickstand Case aids kickstand',
#  'inch display product segment protection RAM memory LED flash Bokeh mode G Z40 Gorilla Glass Android edition GB GB LTE',
#  'description Quality LED ring light grains Function light night dark places ring light settings del 5S Modelo Compatible iPhone iPhone iPhone iPhone iPhone iPhone iPhone Plus IPhone S IPhone S Plus iPhone',
#  'side mirror screw size phone phone mount smartphons cell phones rearview mirror motorcycle tools degree mount phone holder experience Features cell phones appearance design -Easy motorcycle phone holder rearview mirror tools -Can love phone rotation angel adjustment jaw lock love phone motorcycle cell phones appearance design -Easy motorcycle phone holder rearview mirror tools -Can love phone rotation angel adjustment jaw lock love phone motorcycle Attaches max mm Motorbike Holder Motorcycle Buckle Structure Phone Cradle -Universal Heavy Duty Motorcycle Phone Mount -With Four Features -Universal Heavy Duty Motorcycle Phone Mount -With Four',
#  'Memory card storage demands quality digital video cameras resolution image recording devices Kingston GB SDHC Class',
#  'DESIGNED V15 case cover cutouts buttons ports scratch material protection smartphone scratches scrapes Protection cover safeguard smartphone drops nicks bumps slipes shocks scratches Vivo Vivo Pro Vivo V15 Pro Vivo Vivo V15 Pro scrubes',
#  'Armor TPU Case Corners needs customer protection phone phone crowd looks quality eco materials textures Phone case degree protection device profile shock proof corners phone impact sides drop phone protection lips sides phone safety screen camera fall surface phone model care details phone sensors camera speakers case carbon fibre accents side looks phone phone Material grade environment TPU materials odour environment health cases material deformation tear finger print scratch Golden Sand Anti Shock Motorola Vision Armor Slim Case Golden Sand Armor Series Air Cushion Technology Lips Camera Screen Armor Case Perfect Fit Golden Sand Armor Case mould Unique Brushed Silk Carbon Fibre Texture Armor Unique Smooth Silk Brushed Texture High Quality washable',
#  'Description % Brand quality phone bracket stretch phone Phone bracket stretch hole slot padded sides tier sponge clamps love machine - cm width',
#  'devices finish TOUGH Fingerprint proof tear dream treat eyes lip build design screen surface Case Edges screen scratches Scratch durability case Phone comfort use phone opening skin device design button seamless compatibility fitting installation case chance loss case phone resistance profile design ease comfort handling weight bulk cases Case Phone Message customers products purchases orders business day delivery products world class services brands GoldKart Gold Series Matte Finish Hard Cases Matte Density PolyCarbonate Matte Finish Minimalist Matte Finish Super Proof Scratch Proof Maximum Protection Precise Cutouts Slim Form Fitted Corner Impact Feather Light Feather Light Package Content GoldKart Seller',
#  'time use film sticker wall cleaning pad place press seconds item pad while NOTE POWERFUL ADSORPTION ABILITY nail cleaning Specification Name Function sticker Color Package pieces Weight lb Size cm cm Flourish Lama Material High Proformance Nano Rubber Feature Universal Black',
#  'touch phone sim option connectivity multimedia options possibilities entertainment',
#  'reason business life stress experience Warranty Policy Months Warranty Carefree Service Purchase',
#  'mobile display screen resolution HD pixels operating system device core GHz processor GB battery mAh camera mobile camera sensors fingerprint sensor performance games phone T820 board storage GB option memory GB VOTO V3 cm Android Nougat Cortex A7 RAM MP Accelerometer Mali MP1 GPU Yes',
#  'manufacturer party product refurbishment process test replacement parts cleaning inspection process product accessories headphones month supplier warranty Product India',
#  'mm Thickness Package Popio Combo Xiaomi Redmi Pro Carbon Fiber Cover Premium Quality Perfect Finish Glass Screen Protector Contains Carbon Fiber Cover Glass Dry Wet Wipes Dust Absorber Guide Sticker',
#  'hassle pockets phone wallet house card leather storage pouch design pocket transaction cards leather surface case phone look cover phone protection scratches damages dirt phone leather wallet phone cover look gadget durability material benefit wallet years phone cover wallet border design sides wallet fraying stitches longevity leather wallet leather cover card wallet snap button closure closure items bag snaps way contents bag',
#  'footprint design adapts environments key ringtone desk wall hotel rooms meeting rooms supermarket checkouts Alcatel T06',
#  'Colour size name . display corner design hand feel display world core processor technology system level optimisations power consumption battery life quality camera photos lighting conditions portraits features | GB Qualcomm snapdragon nm finfet Miui beautify',
#  'products spirit designers dedication quality craftsmanship feather cases shell impact core shape case strength size weight design access device controls ports openings glare flash snapshots audio marriage design elements materials protection device Urban Armor Gear unison maximizes',
#  'budget fashion phone patterns diamonds effects manufacturer personalization options themes wallpapers MP3-grade ringtones voice recorder hands speaker Prism',
#  'vibes sound drivers surroundings bass beat apace tracks life boAt Bassheads Super Extraaa Bass Plug Nirv',
#  'vibes sound drivers surroundings bass beat apace tracks life boAt Bassheads Super Extraaa Bass Plug Nirv',
#  'Honor lite smartphone touchscreen display resolution pixels pixels ppi pixels inch Honor lite octa core hisilicon processor gb ram phone gb storage gb card cameras camera rear shooter selfies Honor battery Kirin Honor lite android 3000mah',
#  'history watch phone book synchronization records Sms synchronization reminder message watch vibrate ring watch messaging icon ios restriction messages view notification message apps phone twitter instagram music heart rate monitor sleep monitor reminder pedometer recorder alarm watch calculator weather time synchronization waterproof use swim bath iphone notifier facebook whatsapp',
#  'Speakers bass sound line button convinient call mic',
#  'hole design fit phone model phone holes Fashion case design auto focus shell rubber quality material hand feel trends phone crack scratch Fashion colors fashion colors market design edge case phone back camera proction phone bezels protection screen camera case ring holder degree design movies auto car holder access buttons ports bezel detail OPPO A5S OPPO A7',
#  'device holder things gym water proof Velcro arm band arms circumference inches compatibility hand band case smartphones inches wrist arm device precision cut outs access headphones ports controls armband hand soap water air machine armband damage Waterproof',
#  'music power x - bass fidelity sound reproduction thing music time colors style bass precision neodymium drivers bass frequency response ease transition diaphragms diaphragm fidelity sound audio spectrum response times reproduction ear earphones grip Features tangle cable volume control connector L shape minijack sizes silicone earplugs nu republic jaxx l jaxx l diaphragms mic',
#  'phones today part life collection purpose feature phone phone collection brand segments phone messaging MP3 songs choice Screen phone . Cm display quality viewing experience picture video keypad dialing numbers messages phone camera Feature images click flash pictures area phone radio feature radio station music player songs MP3 format Storage Capacity phone storage capacity pictures songs movies Connectivity phone connectivity option songs pictures devices hassle wires phone ion battery battery saving mode press seconds battery saving mode hours talk time battery go Currency detector mobile feature currency light note currency Kall Feature Kall KALL Size Kall K3310 Smart Camera Light FM Radio FM upto GB SIM Super Battery Li mAh Light sham',
#  'history watch phone book synchronization records Sms synchronization reminder message watch vibrate ring watch messaging icon ios restriction messages view notification message apps phone twitter instagram music heart rate monitor sleep monitor reminder pedometer recorder alarm watch calculator weather time synchronization waterproof use swim bath iphone notifier facebook whatsapp',
#  'manufacturer party product refurbishment process test replacement parts cleaning inspection process product accessories headphones month supplier warranty Product India',
#  '% Brand quality phone bracket stretch phone Phone bracket hole stand stretch hole stand slot padded sides tier sponge clamps love machine - smartphones cell phones cases Product Quality:1 ATTACHES video pictures phone webcam.2 - tripods.3 PHONE SCREEN TRIPOD CONNECTOR scratching marks screen.4 phone place conditions.5 MOUNTS tripods screw course tripod problems phones fit plus3 plus3 T cm width tripod tripod tripod tripod HUMBLE Phone Tripod Adapter Works iPhone Tripod Mount iPhone SE 6S 6S Plus Samsung Galaxy S8 S7 S6 S5 S4 S3 S2 Cell Phone Tripod Mount tripod mount STANDARD TRIPOD Phone Tripod Adapter mini ULTRASTRONG FIX Cell Phone Tripod Adapter mount Cell Phone Tripod Adapter tripod Cell Phone Tripod Adapter iPhone 5S 5C Samsung Galaxy S6 S6 Edge S5 S4 S3 A7 A5 A3 OnePlus Two Nokia Microsoft Lumia',
#  'quality sound speaker solution music smartphones tablets battery hours playtime noise speakerphone calls speaker colors injection finishing eye contrast style strap hook strap music world style audio hand hand companion JBL GO JBL GO Bluetooth JBL GO JBL GO',
#  'inch display product segment protection RAM memory LED flash Bokeh mode G Z40 Gorilla Glass Android edition GB GB LTE',
#  '✨ phones charging devices phone holder vehicles air vents - rubber material base grip worry Color cm Input Voltage 5V 2A 1.5A % Phones⋆ Package » Car Charger » » » ✨ Product Highlights ➾ 10W Fast Charging ➾ Air Vent Phone Holder Mount Infrared Auto Single Operation Qi Quick Charging Anti travel.⋆ Specification:⋆ ☑ Black ☑ Material PC+ABS ☑ Size ☑ Power 10W ☑ Input Current ☑ Charging Current 1.2A ☑ Executive Standard Qi Working Distance mm ☑ Charging Efficiency ☑ Adapted Models Qi Standard Wireless Charging Mobile Wireless Air Outlet Clip Cable User Manual',
#  ...]

# %% [markdown]
# **Trial 1:**

# %%
vectorizer1 = TfidfVectorizer(df,lowercase = True, analyzer='word', stop_words='english', min_df = 0.1,max_df = 0.9)
tfidfmat1 = vectorizer1.fit_transform(df)
print("TFIDF shape: ", tfidfmat1.shape)
print("Terms in TFIDF: ",vectorizer1.get_feature_names())
# Out:
# TFIDF shape:  (3414, 27)
# Terms in TFIDF:  ['access', 'android', 'battery', 'buttons', 'camera', 'case', 'cover', 'design', 'device', 'display', 'experience', 'features', 'gb', 'material', 'mobile', 'music', 'phone', 'phones', 'power', 'product', 'protection', 'quality', 'scratches', 'screen', 'smartphone', 'technology', 'time']

# %%
tfidfmat1
# Out:
# <3414x27 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16118 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **Trial 1.2 : Top 5**
#
# ---
#
# simple topn

# %%
def topn_indices(tfidfmat,n):
  lst = []
  lst = [tfidfmat.todense()[i].argsort()[:,-n:] for i in range(tfidfmat.shape[0])]
  return lst

# %%
def get_topn_multi_keywords(tfidfmat,n,terms):
  topn_lst_indices = topn_indices(tfidfmat,n)
  topn_lst_indices = np.array(topn_lst_indices).reshape((tfidfmat.shape[0],n))
  doc_keywords = [[terms[i] for i in l] for l in topn_lst_indices]
  return doc_keywords

# %%
doc_keywords = get_topn_multi_keywords(tfidfmat1,3,terms)
df_tfidf_out1 = pd.DataFrame(data = {'Product_name': data['Product_name'],'prod_des':data['prod_des'],'multi_keywords':doc_keywords})
df_tfidf_out1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2b4b842d9fbb> in <module>()
# ----> 1 doc_keywords = get_topn_multi_keywords(tfidfmat1,3,terms)
#       2 df_tfidf_out1 = pd.DataFrame(data = {'Product_name': data['Product_name'],'prod_des':data['prod_des'],'multi_keywords':doc_keywords})
#       3 df_tfidf_out1
#
# NameError: name 'terms' is not defined
